# %%
# !git clone https://github.com/matterport/Mask_RCNN.git

# %%
cd Mask_RCNN/
# Out:
# /content/Mask_RCNN

# %%
# !pip install -r requirements.txt

# %%
# !python setup.py install

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cp mask_rcnn_coco.h5 /content/

# %%
cd /content/
# Out:
# /content

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9c8c4a2f-22f1-49d2-94cb-e8d4dd9fb19d" name="files[]" multiple disabled />
#      <output id="result-9c8c4a2f-22f1-49d2-94cb-e8d4dd9fb19d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 9.jpg to 9.jpg
# User uploaded file "9.jpg" with length 781985 bytes

# %%
from mrcnn import model
from mrcnn.config import Config
from PIL import Image
import numpy as np

# %%
class CocoConfig(Config):
    """Configuration for training on MS COCO.
    Derives from the base Config class and overrides values specific
    to the COCO dataset.
    """
    # Give the configuration a recognizable name
    NAME = "coco"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 1

    # Uncomment to train on 8 GPUs (default is 1)
    # GPU_COUNT = 8

    # Number of classes (including background)
    NUM_CLASSES = 1 + 80  # COCO has 80 classes

# %%
mo = model.MaskRCNN(mode="inference", config=CocoConfig(),model_dir='mask_rcnn_coco.h5')

# %%
t=np.array(Image.open('9.jpg'))

# %%
roi = mo.detect([t],verbose=0)[0]

# %%
from mrcnn.visualize import *

# %%
mask=roi['masks'][:,:,0].astype(np.uint8)

# %%
apply_mask(t,roi['rois'],mask,roi['class_ids'])

# %%
save_image(t, "m.jpg", roi['rois'], roi['masks'],roi['class_ids'],roi['scores'],coco_class_names,filter_classs_names=['bottle', 'wine glass'],scores_thresh=0.9,mode=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f26ec5249d33> in <module>()
# ----> 1 visualize.save_image(t, "m.jpg", r['rois'], r['masks'],r['class_ids'],r['scores'],coco_class_names,filter_classs_names=['bottle', 'wine glass'],scores_thresh=0.9,mode=0)
#
# NameError: name 'visualize' is not defined
